# %% [markdown]
# Run both code cells below by clicking into the cell and then pressing CTRL/CMD + ENTER

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
base_path = "drive/MyDrive/llms4linguists"

with open(f"{base_path}/data/hello_world.txt") as f:
  content = f.readlines()

if os.path.isdir(f"{base_path}/notebooks/") and os.path.isdir(f"{base_path}/data/"):
  print(str(content[0]))
else:
  print(str(content[1]))
# Out:
# Congratulations, you completed the homework!
